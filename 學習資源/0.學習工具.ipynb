# %% [markdown]
# ## 電腦教室教師機
# ![broadcast.png](attachment:broadcast.png)

# %% [markdown]
# ### All to one
# ![Monitor All](http://italc.sourceforge.net/screenshots/italc-1.0.6_1.jpg)

# %% [markdown]
# +++
# ### Download iTALC
#
# https://github.com/iTALC/italc/releases

# %% [markdown]
# +++
# ### 圖解 iTALC 安裝、設定與使用方法
#
# http://jamyy.us.to/blog/2012/04/3705.html
