# %% [markdown]
# # 解題心法
# 1. Compuational Thinking
# 2. 一次只走一步
#  - 不會同時走
#  - 做完這一步, 才會走下一步
# 3. 善用關鍵字、搜尋引擎

# %% [markdown]
# ## 1. 给你一个list L,对L进行升序排序并输出 (WK2 discuss)
#
# L=[2,8,3,50],
# 輸出结果为[2,3,8,50]。
#
# ### Tips :
# 1. 使用list變數
#  - list的用法
# 2. 找最大（小）值
# 3. 資料分組的方法
# 4. 演算法
#  - 4個數字 和 400 個數字有什不一樣？
# 5. 使用for...loop
# 6. 使用兩層迴圈

# %% [markdown]
# +++
# ### 善用搜尋工具（關鍵字 list）
# ![practice1.png](attachment:practice1.png)

# %% [markdown]
# +++
# ### 善用搜尋工具（關鍵字 for loop）
# ![practice2.png](attachment:practice2.png)

# %% [markdown]
# ## 2. 請列印出 九九乘法表
# ### 並且輸出以下格式
# ![practice3.png](attachment:practice3.png)
#
# ### Tips:
# 1. for loop
# 2. 字串格式化
# 3. 跳脫字元
# 4. print函數的進階使用方法

# %% [markdown]
# ## 3. 請撰寫一程式，讓使用者可以分別輸入2位同學的名稱及分數，輸出結果並如下排列： (斜體部分為執行程式時輸入)
#
#
# 請輸入A同學姓名: *Name_A*
#
# 請輸入A同學分數: *90*
#
# 請輸入B同學姓名: *Name_B*
#
# 請輸入B同學分數: *80*
#
# 姓名             分數
#
# Name_A     90
#
# Name_B     80
#
#
# ### Tips：
# 1. 使用 input() 函式
# 2. 跳脫字元
# ![python006.png](attachment:python006.png)

# %% [markdown]
# ## 4. 精靈國的計程車由500精靈幣開始跳表，自上車後開始計算公里數，每開1公里加收1000精靈幣，下車前再收5000精靈幣作為清潔費。請問普羅搭乘計程車移動28公里應付多少錢？(請撰寫一程式計算該結果並加以輸出)
#
# ### Tips：
#
# 1. Computational Thinking
# 2. 保持冷靜

# %% [markdown]
# ## 5. 輸入三角形的三個邊長
# ## 輸出三角形面積
#
# ### Tips：
# 1. 上網找出計算三角形面積的公式
# ![python001.png](attachment:python001.png)
# 2. 要能判斷使用者輸入的三個邊長是否合法
# 3. 帶入公式計算三角形面積
# 4. 輸出面積 =

# %% [markdown]
# ## 6. 將以下句子全部輸出成小寫，"PLEASE CONVERT THIS SENTENCE TO LOWER CASE."
# ### Tips:
# 1. 請上網查找字串的方法
# 2. Keyword 大小寫轉換

# %% [markdown]
# ## 7. 請修正下列程式碼，使其能正確執行：
# ```python
# bornYear = input("請輸入你的出生年份：")
# nowYear = input("請輸入今年的年份：")
# age = nowYear - bornYear
# print("你今年%d歲" % age)
# ```
#
# ### Tips:
# 1. 資料型別

# %% [markdown]
# ## 8. 輸入年月日, 然後輸出在那一年經過了幾天 （從1/1到輸入的那一天)
#
# 例如：
#
# 輸入 2017, 2 , 3
#
# 輸出 34
#
# ### Tips:
# 1. 要判斷是否閏年
# ![python004.png](attachment:python004.png)
# 2. 要判斷日期是否符合規則

# %% [markdown]
# ## 9.讓使用者分別輸入身高(cm)及體重(kg)後，進一步計算出其身體質量指數(BMI值)，並根據下表輸出該BMI值及其分級。例如輸入身高為160公分、體重50公斤，則輸出：BMI值為19.53(顯示至小數第二位)，屬正常範圍。
#
# ![Table](http://pythonpro.weebly.com/uploads/9/9/3/0/9930914/6937765.png?535)
#
# ### Tips:
# 1. 上網找BMI計算公式
# ![python003.png](attachment:python003.png)
# 2. 使用 if...elif..else
# 3. 要有點耐心

# %% [markdown]
# ## 10. 一份數學考卷共有14題，為了使及格率提高，給分方式如下：答對1～8題，每題以8分計；答對9題以上者，前8題仍以8分計，但第9題開始則每題以6分計。請根據以上敘述撰寫一支程式，讓使用者輸入答對題數，再經程式計算後輸出得分。
#
# 例：
# 請輸入您答對幾題： 7
# 您得到：  56分
#
# 請輸入您答對幾題： 100
# 別開完笑了！
#
# 請輸入您答對幾題： 0
# 您的程度還真爛！
#
# ### Tips:
# 1. Computional Thinking
# 2. 保持冷靜
# 3. 畫張表自己分析一下
# 4. if...elif..else
# ![python002.png](attachment:python002.png)

# %% [markdown]
# ## 11.請修改習題5的程式碼：若三數可形成三角形，請判斷圍成的三角形是為銳角、直角或鈍角三角形，然後輸出結果。
#
# 例：
# 輸入三個邊：  *5 7 6*
# 答案： 這是銳角三角形
#
# 輸入三個邊：  *5 3 4*
# 答案： 這是直角三角形
#
#
#
# ### Tips：
# 1. 對使用者輸入的資料要先做處理
#  - 怎樣把輸入的字串切成三個整數？
# 2. 三個邊的邊長要不要先排序過？
# 3. 是否合法三角形
#  - 三角形三邊合法的判斷式？
# 4. 上網找三角形 銳角、直角或鈍角 的判斷式？
# ![7.png](attachment:7.png)
# 5. if...then
# 6. 輸出答案

# %% [markdown]
# ## 12. 金字塔是世界七大奇景之一，請利用for迴圈寫出如下圖所示的4層金字塔圖形。
#
# ```python
#    *
#
#   * *
#
#  * * *
#
# * * * *
# ```
#
#
# ### Tips:
# 1. for loop
# 2. 每一層分兩次印, 第一次印空白, 第二次印＊號
# 3. 找出演算法口訣
# 4. 使用print 函數的進階功能
# ### 5.如果印 100層, 要怎寫？

# %% [markdown]
# ## 13. 輸出當前時間, 間隔三秒後，再次輸出當前時間。
# 例：
# 當前時間 2017-04-23 21:02:00
# 三秒以後 2017-04-23 21:05:00
#
# ### Tips:
# 1. 上網找時間有關的模組(module)
# ![6.png](attachment:6.png)
# 2. 使用現成的時間方法 (method)

# %% [markdown]
# ## 14. 用Python每秒鐘ping一次Google, 並輸出回應是否成功
#
# ### Tips:
# ![python005.png](attachment:python005.png)

# %% [markdown]
# ## 15. 在範圍 0~99 猜數字
#
# 要紀錄猜的次數
# 要紀錄完幾回合
# 要能算出平均每一回合花幾次猜中
# 太大或太小要能提示user
#
# ### Tips:
# 1. 要有亂數
# ![python007.png](attachment:python007.png)
# 2. 要幾個迴圈？
# 3. 資料用什來保存紀錄？
# 4. 演算法？

# %% [markdown]
# ## 16. 利用Python來批次自動更改檔案名稱
#
# ### Tips:
# 1. 開始找吧, 一定有人幹過這檔事
# ![python008.png](attachment:python008.png)

# %% [markdown]
# ## 17.輸入任意十進位整數,將其轉換為二進位輸出
# ### Tips:
# 1. 自己寫一個函式來轉換
# ![python009.png](attachment:python009.png)
# 2. 找現成的 python 函數來轉換
# ![python010.png](attachment:python010.png)

# %% [markdown]
# ![python012.png](attachment:python012.png)
#
# http://python-basics.blogspot.tw/2005/10/blog-post.html

# %% [markdown]
# ## 18.題目：有1、2、3、4個數字，能組成多少個互不相同且無重複數字的三位元數？都是多少？
#
# 例：
# 1,2,3
# 1,3,4
# 2,3,4
# .....
#
# Tips:
# 1. 想想看,這要用幾層迴圈？
# 2. 什叫做互不相同且無重複？

# %% [markdown]
# ## 19.題目：企業發放的獎金根據利潤抽成。利潤(I)低於或等於10萬元時，獎金可提10%；
#     利潤高于10萬元，低於20萬元時，低於10萬元的部分按10%提成，高於10萬元的部分，可提成7.5%；
#     20萬到40萬之間時，高於20萬元的部分，可提成5%；
#     40萬到60萬之間時高於40萬元的部分，可提成3%；
#     60萬到100萬之間時，高於60萬元的部分，可提成1.5%，
#     高於100萬元時，超過100萬元的部分按1%提成，從鍵盤輸入當月利潤I，求應發放獎金總數？

# %% [markdown]
# ## 20.題目：一個整數，它加上100後是一個完全平方數，再加上168又是一個完全平方數，請問該數是多少？
# Tips:
# 1. int i
# 2. i + 100 = x*x
# 3. i + 100 + 168 = y*y
# 4. i = ?

# %% [markdown]
# ## 21.身份證號碼檢查
#
# 我國的身分證字號有底下這樣的規則，因此對於任意輸入的身分證字號可以有一些基本的判斷原則，請您來判斷一個身分證字號是否是正常的號碼(不代表確有此號、此人)。
#
# (1) 英文代號以下表轉換成數字
#
#       A=10 台北市     J=18 新竹縣     S=26 高雄縣
#       B=11 台中市     K=19 苗栗縣     T=27 屏東縣
#       C=12 基隆市     L=20 台中縣     U=28 花蓮縣
#       D=13 台南市     M=21 南投縣     V=29 台東縣
#       E=14 高雄市     N=22 彰化縣     W=32 金門縣
#       F=15 台北縣     O=35 新竹市     X=30 澎湖縣
#       G=16 宜蘭縣     P=23 雲林縣     Y=31 陽明山
#       H=17 桃園縣     Q=24 嘉義縣     Z=33 連江縣
#       I=34 嘉義市     R=25 台南縣
#
#   (2) 英文轉成的數字, 個位數乘９再加上十位數的數字
#
#   (3) 各數字從右到左依次乘１、２、３、４．．．．８
#
#   (4) 求出(2),(3) 及最後一碼的和
#
#   (5) (4)除10 若整除，則為 real，否則為 fake
#
#  例： T112663836
#
# 2 + 7*9 + 1*8 + 1*7 + 2*6 + 6*5 + 6*4 + 3*3 + 8*2 + 3*1 + 6 = 180
#
# 除以 10 整除，因此為 real
#
# 輸入說明 ：
# 一組身分證號碼
#
# 輸出說明 ：
# 輸出 real or fake"""
